# %%
# %pip install scikit-learn numpy pandas matplotlib
# %pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: scikit-learn in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (1.26.1)
# Requirement already satisfied: pandas in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (2.1.2)
# Requirement already satisfied: matplotlib in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (3.8.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\asoka\documents\gitprojects\simple-linear-regression\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import necessary modules
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Salary_dataset.csv")

# %%
model = LinearRegression()
x=np.array(df[["YearsExperience"]])
y=np.array(df["Salary"])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=4)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

score = r2_score(y_test, y_pred)
print("The accuracy of our model is {}%".format(round(score, 2) *100))
# Out:
# The accuracy of our model is 92.0%

# %%
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_test, y_pred, color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
